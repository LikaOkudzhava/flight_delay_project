# %%
    # Import packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, date, time, timedelta

import init
import baseline_model as bm

# %%
# Load data
df_train = init.load_data("train")

# %%
# Calculate duration
df_train["DURATION"] = (df_train.STA - df_train.STD) / timedelta(minutes = 1)

# %%
# Remove SCH and DEL observations
df_small = df_train[(df_train["STATUS"] != "SCH") & (df_train["STATUS"] != "DEL")]

# %%
sns.scatterplot(df_small,x="DURATION",y="target")
# Out:
# <Axes: xlabel='DURATION', ylabel='target'>

# %%
sns.pairplot(df_small)
